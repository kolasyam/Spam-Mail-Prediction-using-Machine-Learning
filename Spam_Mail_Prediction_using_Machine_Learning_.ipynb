# %% [markdown]
# <a href="https://colab.research.google.com/github/kolasyam/Spam-Mail-Prediction-using-Machine-Learning/blob/main/Spam_Mail_Prediction_using_Machine_Learning_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection & Pre-Processing

# %%
#loading the data from csv file to a padas Dataframe
raw_mail_data = pd.read_csv('/content/mail_data.csv')

# %%
print(raw_mail_data)
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
#replace the null values with a null string
mail_data = raw_mail_data.where((pd.notnull(raw_mail_data)),'')

# %%
# printing the first 5 rows fo the dataframe
mail_data.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
# checking the number of rows and columns in the dataframe
mail_data.shape
# Out:
# (5572, 2)

# %% [markdown]
# Label Encoding

# %%
# label spam mail as 0; ham mail as 1;
mail_data.loc[mail_data['Category']== 'spam', 'Category',] = 0
mail_data.loc[mail_data['Category']== 'ham', 'Category',] = 1

# %%
mail_data.head()
# Out:
#   Category                                            Message
# 0        1  Go until jurong point, crazy.. Available only ...
# 1        1                      Ok lar... Joking wif u oni...
# 2        0  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        1  U dun say so early hor... U c already then say...
# 4        1  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# spam - 0

# %% [markdown]
# ham -1

# %%
# seperating the data as texts and label
X = mail_data['Message']
Y = mail_data['Category']

# %%
print(Y)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: Category, Length: 5572, dtype: object

# %% [markdown]
# Splitting the data into training data & testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
# print(X.shape)
# print(X_train.shape)
# print(X_test.shape)
print(Y_train)
# Out:
# 1642    1
# 2899    1
# 480     1
# 3485    1
# 157     1
#        ..
# 905     1
# 5192    1
# 3980    1
# 235     0
# 5157    1
# Name: Category, Length: 4457, dtype: object

# %% [markdown]
# Feature Extraction

# %%
#transform the test data to feature vectors that can used as input to the logistic regression
feature_extraction = TfidfVectorizer(min_df=1,stop_words='english',lowercase=True)
X_train_features = feature_extraction.fit_transform(X_train)
X_test_features = feature_extraction.transform(X_test)
# convert Y_train and Y_test values as integers
Y_train = Y_train.astype('int')
Y_test = Y_test.astype('int')

# %%
print(X_train_features)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 34641 stored elements and shape (4457, 7454)>
#   Coords	Values
#   (0, 3321)	0.2638802854739516
#   (0, 3789)	0.4750235197588447
#   (0, 3822)	0.37729728742748087
#   (0, 2719)	0.299459437576315
#   (0, 5895)	0.415102954745324
#   (0, 6695)	0.3616065178053154
#   (0, 2353)	0.2545072203817634
#   (0, 4346)	0.3238008504874723
#   (1, 3365)	0.5510421389942982
#   (1, 1858)	0.5163195438969705
#   (1, 4343)	0.6555659308129219
#   (2, 3185)	0.3663054742561573
#   (2, 3025)	0.3502912545366897
#   (2, 5672)	0.32606636481997364
#   (2, 6597)	0.40097414833733686
#   (2, 6215)	0.43979370278404856
#   (2, 4267)	0.531599749449541
#   (3, 6514)	0.16150638564730485
#   (3, 1168)	0.20930686903969756
#   (3, 1689)	0.25710735243209026
#   (3, 2322)	0.2448089292310804
#   (3, 3987)	0.27640333020388075
#   (3, 4035)	0.2823414163958387
#   (3, 6789)	0.1937220783869856
#   (3, 1681)	0.22454159820679026
#   :	:
# ...

# %% [markdown]
# Training the Model
#
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression model with the training data
model.fit(X_train_features, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluating the Trained Model

# %%
# prediction on training data

prediction_on_training_data = model.predict(X_train_features)
accuracy_on_training_data = accuracy_score(Y_train, prediction_on_training_data)

# %%
print("Accuracy on training data:", accuracy_on_training_data)
# Out:
# Accuracy on training data: 0.9681400044873233

# %%
# prediction on testing data

prediction_on_testing_data = model.predict(X_test_features)
accuracy_on_testing_data = accuracy_score(Y_test, prediction_on_testing_data)

# %%
print("Accuracy on testing data:", accuracy_on_testing_data)
# Out:
# Accuracy on testing data: 0.9704035874439462

# %% [markdown]
# Building a Predictive System

# %%
input_mail = ["We still have final few seats available, and to make this exclusive opening even better, a $500 scholarship is up for grabs for early applicants like you."]
# convert text to feature vectors
input_data_features = feature_extraction.transform(input_mail)

 # making prediction

prediction = model.predict(input_data_features)
print(prediction)
if prediction[0] == 1:
  print("Ham mail")
else:
  print("Spam mail")
# Out:
# [1]
# Ham mail

# %%
import joblib

joblib.dump(model, "spam_classifier_model.pkl")
joblib.dump(feature_extraction, "tfidf_vectorizer.pkl")
# Out:
# ['tfidf_vectorizer.pkl']

# %%
import joblib

# Load saved artifacts
model = joblib.load("spam_classifier_model.pkl")
feature_extraction = joblib.load("tfidf_vectorizer.pkl")

# New email text
input_mail =["Congratulations! You have won a free coupon. Click now"]
# Convert text to features
input_data_features = feature_extraction.transform(input_mail)

# Predict
prediction = model.predict(input_data_features)

if prediction[0] == 1:
    print("Ham mail")
else:
    print("Spam mail")
# Out:
# Spam mail
